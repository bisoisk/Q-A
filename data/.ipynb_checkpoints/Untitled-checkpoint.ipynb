# %%
import pandas as pd

import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/rajath/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import os

PATH='text_data/S08_set1_a'
PATH2='.txt.clean'
file_range=range(1,10)
labels=[]
txt_data=[]

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
stop_words = set(stopwords.words('english'))

# %%
for i in file_range:
    File_Path=PATH+str(i)+PATH2
    print(File_Path)
    file=open(File_Path,'r')
    txt=file.readlines()[1:]    
    txt_data.append(txt)
    topic=txt[0]
    labels.append(topic[:-1])
# Out:
# text_data/S08_set1_a1.txt.clean
# text_data/S08_set1_a2.txt.clean
# text_data/S08_set1_a3.txt.clean
# text_data/S08_set1_a4.txt.clean
# text_data/S08_set1_a5.txt.clean
# text_data/S08_set1_a6.txt.clean
# text_data/S08_set1_a7.txt.clean
# text_data/S08_set1_a8.txt.clean
# text_data/S08_set1_a9.txt.clean

# %%
def remove_stopwords(txt_data):
    for data in txt_data:
        for paragraph in data:
            word_tokens = word_tokenize(paragraph)
            filtered_sentence = [w for w in word_tokens if not w in stop_words]
            print(filtered_sentence)

# %%
remove_stopwords(txt_data)
# Out:
# []
#
#
# []
# A kangaroo is a marsupial from the family Macropodidae (macropods, meaning 'large foot'). In common use the term is used to describe the largest species from this family, the Red Kangaroo, the Antilopine Kangaroo, and the Eastern and Western Grey Kangaroo of the Macropus genus. The family also includes many smaller species which include the wallabies, tree-kangaroos, wallaroos, pademelons and the Quokka, some 63 living species in all.  Kangaroos are endemic to the continent of Australia, while the smaller macropods are found in Australia and New Guinea.
#
# ['A', 'kangaroo', 'marsupial', 'family', 'Macropodidae', '(', 'macropods', ',', 'meaning', "'large", 'foot', "'", ')', '.', 'In', 'common', 'use', 'term', 'used', 'describe', 'largest', 'species', 'family', ',', 'Red', 'Kangaroo', ',', 'Antilopine', 'Kangaroo', ',', 'Eastern', 'Western', 'Grey', 'Kangaroo', 'Macropus', 'genus', '.', 'The', 'family', 'also', 'includes', 'many', 'smaller', 'species', 'include', 'wallabies', ',', 'tree-kangaroos', ',', 'wallaroos', ',', 'pademelons', 'Quokka', ',', '63', 'living', 'species', '.', 'Kangaroos', 'endemic', 'continent', 'Australia', ',', 'smaller', 'macropods', 'found', 'Australia', 'New', 'Guinea', '.']
#
#
# []
# In general, larger kangaroos have adapted much better to changes wrought to the Australian landscape by humans and though many of their smaller cousins are endangered, they are plentiful. They are not farmed to any extent, but wild kangaroos are shot for meat, over which there is controversy.  Steve Dow: "An industry that's under the gun". Sydney Morning Herald online, September 26, 2007.
#
# ['In', 'general', ',', 'larger', 'kangaroos', 'adapted', 'much', 'better', 'changes', 'wrought', 'Australian', 'landscape', 'humans', 'though', 'many', 'smaller', 'cousins', 'endangered', ',', 'plentiful', '.', 'They', 'farmed', 'extent', ',', 'wild', 'kangaroos', 'shot', 'meat', ',', 'controversy', '.', 'Steve', 'Dow', ':', '``', 'An', 'industry', "'s", 'gun', "''", '.', 'Sydney', 'Morning', 'Herald', 'online', ',', 'September', '26', ',', '2007', '.']
#
#
# []
# The kangaroo is an Australian icon: it is featured on the Australian coat of arms,  Australia's coat of arms URL accessed January 6, 2007.  on some of its currency,  The Australian currency URL accessed January 6, 2007.  and is used by many Australian organisations, including Qantas.  The Kangaroo symbol URL accessed January 6, 2007.
#
# ['The', 'kangaroo', 'Australian', 'icon', ':', 'featured', 'Australian', 'coat', 'arms', ',', 'Australia', "'s", 'coat', 'arms', 'URL', 'accessed', 'January', '6', ',', '2007.', 'currency', ',', 'The', 'Australian', 'currency', 'URL', 'accessed', 'January', '6', ',', '2007.', 'used', 'many', 'Australian', 'organisations', ',', 'including', 'Qantas', '.', 'The', 'Kangaroo', 'symbol', 'URL', 'accessed', 'January', '6', ',', '2007', '.']
#
#
# []
#
#
# []
#
#
# []
# The word kangaroo derives from the Guugu Yimidhirr word gangurru, referring to a grey kangaroo.  Etymology of mammal names URL accessed January 7, 2007.  The name was first recorded as "Kangooroo or Kanguru" on 4 August,1770, by Lieutenant (later Captain) James Cook on the banks of the Endeavour River at the site of modern Cooktown, when HM Bark Endeavour was beached for almost seven weeks to repair damage sustained on the Great Barrier Reef.
#
# ['The', 'word', 'kangaroo', 'derives', 'Guugu', 'Yimidhirr', 'word', 'gangurru', ',', 'referring', 'grey', 'kangaroo', '.', 'Etymology', 'mammal', 'names', 'URL', 'accessed', 'January', '7', ',', '2007', '.', 'The', 'name', 'first', 'recorded', '``', 'Kangooroo', 'Kanguru', "''", '4', 'August,1770', ',', 'Lieutenant', '(', 'later', 'Captain', ')', 'James', 'Cook', 'banks', 'Endeavour', 'River', 'site', 'modern', 'Cooktown', ',', 'HM', 'Bark', 'Endeavour', 'beached', 'almost', 'seven', 'weeks', 'repair', 'damage', 'sustained', 'Great', 'Barrier', 'Reef', '.']
#
#
# []
# A common myth about the kangaroo's English name is that it came from the Aboriginal words for "I don't understand you." According to this legend, Captain James Cook and naturalist Sir Joseph Banks were exploring Australia when they happened upon the animal. They asked a nearby local what the creatures were called. The local responded "Kangaroo", meaning "I don't understand you", which Cook took to be the name of the creature.  Tour lecture,  , Dawsonville, GA.
#
# ['A', 'common', 'myth', 'kangaroo', "'s", 'English', 'name', 'came', 'Aboriginal', 'words', '``', 'I', "n't", 'understand', '.', "''", 'According', 'legend', ',', 'Captain', 'James', 'Cook', 'naturalist', 'Sir', 'Joseph', 'Banks', 'exploring', 'Australia', 'happened', 'upon', 'animal', '.', 'They', 'asked', 'nearby', 'local', 'creatures', 'called', '.', 'The', 'local', 'responded', '``', 'Kangaroo', "''", ',', 'meaning', '``', 'I', "n't", 'understand', "''", ',', 'Cook', 'took', 'name', 'creature', '.', 'Tour', 'lecture', ',', ',', 'Dawsonville', ',', 'GA', '.']
# Kangaroo soon became adopted into standard English where it has come to mean any member of the family of kangaroos and wallabies.  Male kangaroos are called bucks, boomers, jacks, or old men; females are does, flyers, or jills, and the young ones are joeys.  Animal Bytes: Kangaroo and Wallaby URL accessed January 7, 2007.  The collective noun for kangaroos is a mob, troop, or court. Kangaroos are sometimes colloquially referred to as roos.
#
# ['Kangaroo', 'soon', 'became', 'adopted', 'standard', 'English', 'come', 'mean', 'member', 'family', 'kangaroos', 'wallabies', '.', 'Male', 'kangaroos', 'called', 'bucks', ',', 'boomers', ',', 'jacks', ',', 'old', 'men', ';', 'females', ',', 'flyers', ',', 'jills', ',', 'young', 'ones', 'joeys', '.', 'Animal', 'Bytes', ':', 'Kangaroo', 'Wallaby', 'URL', 'accessed', 'January', '7', ',', '2007', '.', 'The', 'collective', 'noun', 'kangaroos', 'mob', ',', 'troop', ',', 'court', '.', 'Kangaroos', 'sometimes', 'colloquially', 'referred', 'roos', '.']
#
#
# []
#
#
# []
#
#
# []
# A Tasmanian Forester (Eastern Grey) Kangaroo in motion.
#
# ['A', 'Tasmanian', 'Forester', '(', 'Eastern', 'Grey', ')', 'Kangaroo', 'motion', '.']
# There are four species that are commonly referred to as kangaroos:
#
# ['There', 'four', 'species', 'commonly', 'referred', 'kangaroos', ':']
# * The Red Kangaroo (Macropus rufus) is the largest surviving marsupial anywhere in the world. Fewer in numbers, the Red Kangaroo occupies the arid and semi-arid centre of the continent. A large male can be 2 metres (6 ft 7 in) tall and weigh 90 kg (200 lb).
#
# ['*', 'The', 'Red', 'Kangaroo', '(', 'Macropus', 'rufus', ')', 'largest', 'surviving', 'marsupial', 'anywhere', 'world', '.', 'Fewer', 'numbers', ',', 'Red', 'Kangaroo', 'occupies', 'arid', 'semi-arid', 'centre', 'continent', '.', 'A', 'large', 'male', '2', 'metres', '(', '6', 'ft', '7', ')', 'tall', 'weigh', '90', 'kg', '(', '200', 'lb', ')', '.']
# * The Eastern Grey Kangaroo (Macropus giganteus) is less well-known than the red (outside of Australia), but the most often seen, as its range covers the fertile eastern part of the continent.
#
# ['*', 'The', 'Eastern', 'Grey', 'Kangaroo', '(', 'Macropus', 'giganteus', ')', 'less', 'well-known', 'red', '(', 'outside', 'Australia', ')', ',', 'often', 'seen', ',', 'range', 'covers', 'fertile', 'eastern', 'part', 'continent', '.']
# * The Western Grey Kangaroo (Macropus fuliginosus) is slightly smaller again at about 54 kg (119 lb) for a large male. It is found in the southern part of Western Australia, South Australia near the coast, and the Darling River basin.
#
# ['*', 'The', 'Western', 'Grey', 'Kangaroo', '(', 'Macropus', 'fuliginosus', ')', 'slightly', 'smaller', '54', 'kg', '(', '119', 'lb', ')', 'large', 'male', '.', 'It', 'found', 'southern', 'part', 'Western', 'Australia', ',', 'South', 'Australia', 'near', 'coast', ',', 'Darling', 'River', 'basin', '.']
# * The Antilopine Kangaroo (Macropus antilopinus) is, essentially, the far-northern equivalent of the Eastern and Western Grey Kangaroos. Like them, it is a creature of the grassy plains and woodlands, and gregarious.
#
# ['*', 'The', 'Antilopine', 'Kangaroo', '(', 'Macropus', 'antilopinus', ')', ',', 'essentially', ',', 'far-northern', 'equivalent', 'Eastern', 'Western', 'Grey', 'Kangaroos', '.', 'Like', ',', 'creature', 'grassy', 'plains', 'woodlands', ',', 'gregarious', '.']
#
#
# []
# In addition, there are about 50 smaller macropods closely related to the kangaroo in the family Macropodidae.
#
# ['In', 'addition', ',', '50', 'smaller', 'macropods', 'closely', 'related', 'kangaroo', 'family', 'Macropodidae', '.']
#
#
# []
#
#
# []
#
#
# []
# Red Kangaroo (Macropus rufus)
#
# ['Red', 'Kangaroo', '(', 'Macropus', 'rufus', ')']
# Europeans have long regarded Kangaroos as strange animals. Early explorers described them as creatures that had heads like deer (without antlers), stood upright like men, and hopped like frogs.  Combined with the two-headed appearance of a mother kangaroo, this led many back home to dismiss them as travellers' tales for quite some time.
#
# ['Europeans', 'long', 'regarded', 'Kangaroos', 'strange', 'animals', '.', 'Early', 'explorers', 'described', 'creatures', 'heads', 'like', 'deer', '(', 'without', 'antlers', ')', ',', 'stood', 'upright', 'like', 'men', ',', 'hopped', 'like', 'frogs', '.', 'Combined', 'two-headed', 'appearance', 'mother', 'kangaroo', ',', 'led', 'many', 'back', 'home', 'dismiss', 'travellers', "'", 'tales', 'quite', 'time', '.']
#
#
# []
# Kangaroos have large, powerful hind legs, large feet adapted for leaping, a long muscular tail for balance, and a small head. Like all marsupials, female kangaroos have a pouch called a marsupium in which joeys complete postnatal development.
#
# ['Kangaroos', 'large', ',', 'powerful', 'hind', 'legs', ',', 'large', 'feet', 'adapted', 'leaping', ',', 'long', 'muscular', 'tail', 'balance', ',', 'small', 'head', '.', 'Like', 'marsupials', ',', 'female', 'kangaroos', 'pouch', 'called', 'marsupium', 'joeys', 'complete', 'postnatal', 'development', '.']
#
#
# []
#
#
# []
#
#
# []
#
#
# []
# Kangaroos are the only large animals to use hopping as a means of locomotion. The comfortable hopping speed for Red Kangaroo is about 20 25 km/h (13 16 mph), but speeds of up to 70 km/h (44 mph) can be attained, over short distances, while it can sustain a speed of 40 km/h (25 mph) for  nearly two kilometres.    This fast and energy-efficient method of travel has evolved because of the need to regularly cover large distances in search of food and water, rather than the need to escape predators.
#
# ['Kangaroos', 'large', 'animals', 'use', 'hopping', 'means', 'locomotion', '.', 'The', 'comfortable', 'hopping', 'speed', 'Red', 'Kangaroo', '20', '25', 'km/h', '(', '13', '16', 'mph', ')', ',', 'speeds', '70', 'km/h', '(', '44', 'mph', ')', 'attained', ',', 'short', 'distances', ',', 'sustain', 'speed', '40', 'km/h', '(', '25', 'mph', ')', 'nearly', 'two', 'kilometres', '.', 'This', 'fast', 'energy-efficient', 'method', 'travel', 'evolved', 'need', 'regularly', 'cover', 'large', 'distances', 'search', 'food', 'water', ',', 'rather', 'need', 'escape', 'predators', '.']
#
#
# []
# Because of its long feet, it cannot walk correctly. To move at slow speeds, it uses its tail to form a tripod with its two forelimbs. It then raises its hind feet forward, in a form of locomotion called "crawl-walking."
#
# ['Because', 'long', 'feet', ',', 'walk', 'correctly', '.', 'To', 'move', 'slow', 'speeds', ',', 'uses', 'tail', 'form', 'tripod', 'two', 'forelimbs', '.', 'It', 'raises', 'hind', 'feet', 'forward', ',', 'form', 'locomotion', 'called', '``', 'crawl-walking', '.', "''"]
#
#
# []
# The average life expectancy of a kangaroo is about 4 6 years.
#
# ['The', 'average', 'life', 'expectancy', 'kangaroo', '4', '6', 'years', '.']
#
#
# []
#
#
# []
#
#
# []
# Different species of kangaroos eat different diets.  Eastern grey kangaroos are predominantly grazers eating a wide variety of grasses whereas some other species (e.g. red kangaroos and swamp wallabies) include significant amounts of shrubs in the diet. The smaller species of kangaroos also consume hypogeal fungi.  Many species are nocturnal  Archives URL accessed January 7, 2007.  and crepuscular,  Columbus Zoo article URL accessed January 7, 2007.  usually spending the days resting in shade and the cool evenings, nights and mornings moving about and feeding.
#
# ['Different', 'species', 'kangaroos', 'eat', 'different', 'diets', '.', 'Eastern', 'grey', 'kangaroos', 'predominantly', 'grazers', 'eating', 'wide', 'variety', 'grasses', 'whereas', 'species', '(', 'e.g', '.', 'red', 'kangaroos', 'swamp', 'wallabies', ')', 'include', 'significant', 'amounts', 'shrubs', 'diet', '.', 'The', 'smaller', 'species', 'kangaroos', 'also', 'consume', 'hypogeal', 'fungi', '.', 'Many', 'species', 'nocturnal', 'Archives', 'URL', 'accessed', 'January', '7', ',', '2007.', 'crepuscular', ',', 'Columbus', 'Zoo', 'article', 'URL', 'accessed', 'January', '7', ',', '2007.', 'usually', 'spending', 'days', 'resting', 'shade', 'cool', 'evenings', ',', 'nights', 'mornings', 'moving', 'feeding', '.']
#
#
# []
# Because of its grazing, kangaroos have developed specialized teeth. Its incisors are able to crop grass close to the ground, and its molars chop and grind the grass. Since the two sides of the lower jaw are not joined together, the lower incisors are farther apart, giving the kangaroo a wider bite. The silica in grass is abrasive, so kangaroo molars move forward as they are ground down, and eventually fall out, replaced by new teeth that grow in the back.
#
# ['Because', 'grazing', ',', 'kangaroos', 'developed', 'specialized', 'teeth', '.', 'Its', 'incisors', 'able', 'crop', 'grass', 'close', 'ground', ',', 'molars', 'chop', 'grind', 'grass', '.', 'Since', 'two', 'sides', 'lower', 'jaw', 'joined', 'together', ',', 'lower', 'incisors', 'farther', 'apart', ',', 'giving', 'kangaroo', 'wider', 'bite', '.', 'The', 'silica', 'grass', 'abrasive', ',', 'kangaroo', 'molars', 'move', 'forward', 'ground', ',', 'eventually', 'fall', ',', 'replaced', 'new', 'teeth', 'grow', 'back', '.']
#
#
# []
#
#
# []
#
#
# []
# Despite having a herbivorous diet similar to ruminants such as cattle which release large quantities of methane through exhaling and eructation, kangaroos release virtually none. The hydrogen byproduct of fermentation is instead converted into acetate, which is then used to provide further energy. Scientists are interested in the possibility of transferring the bacteria responsible from kangaroos to cattle, since the greenhouse gas effect of methane is 23 times greater than that of carbon dioxide.  Radio Australia - Innovations:
#
# ['Despite', 'herbivorous', 'diet', 'similar', 'ruminants', 'cattle', 'release', 'large', 'quantities', 'methane', 'exhaling', 'eructation', ',', 'kangaroos', 'release', 'virtually', 'none', '.', 'The', 'hydrogen', 'byproduct', 'fermentation', 'instead', 'converted', 'acetate', ',', 'used', 'provide', 'energy', '.', 'Scientists', 'interested', 'possibility', 'transferring', 'bacteria', 'responsible', 'kangaroos', 'cattle', ',', 'since', 'greenhouse', 'gas', 'effect', 'methane', '23', 'times', 'greater', 'carbon', 'dioxide', '.', 'Radio', 'Australia', '-', 'Innovations', ':']
# "Methane In Agriculture." 15 August  2004. Retrieved 28 August 2007.
#
# ['``', 'Methane', 'In', 'Agriculture', '.', "''", '15', 'August', '2004', '.', 'Retrieved', '28', 'August', '2007', '.']
#
#
# []
#
#
# []
#
#
# []
# Kangaroos have few natural predators. The Thylacine, considered by palaeontologists to have once been a major natural predator of the kangaroo, is now extinct. Other extinct predators included the Marsupial Lion, Megalania and the Wonambi. However, with the arrival of humans in Australia at least 50,000 years ago and the introduction of the dingo about 5,000 years ago, kangaroos have had to adapt.   The mere barking of a dog can set a full-grown male boomer into a wild frenzy.   Wedge-tailed Eagles and other raptors usually eat kangaroo carrion. Goannas and other carnivorous reptiles also pose a danger to smaller kangaroo species when other food sources are lacking.
#
# ['Kangaroos', 'natural', 'predators', '.', 'The', 'Thylacine', ',', 'considered', 'palaeontologists', 'major', 'natural', 'predator', 'kangaroo', ',', 'extinct', '.', 'Other', 'extinct', 'predators', 'included', 'Marsupial', 'Lion', ',', 'Megalania', 'Wonambi', '.', 'However', ',', 'arrival', 'humans', 'Australia', 'least', '50,000', 'years', 'ago', 'introduction', 'dingo', '5,000', 'years', 'ago', ',', 'kangaroos', 'adapt', '.', 'The', 'mere', 'barking', 'dog', 'set', 'full-grown', 'male', 'boomer', 'wild', 'frenzy', '.', 'Wedge-tailed', 'Eagles', 'raptors', 'usually', 'eat', 'kangaroo', 'carrion', '.', 'Goannas', 'carnivorous', 'reptiles', 'also', 'pose', 'danger', 'smaller', 'kangaroo', 'species', 'food', 'sources', 'lacking', '.']
#
#
# []
# Along with dingos and other canids, introduced species like foxes and feral cats also pose a threat to kangaroo populations. Kangaroos and wallabies are adept swimmers, and often flee into waterways if presented with the option. If pursued into the water, a large kangaroo may use its forepaws to hold the predator underwater so as to drown it.  Canadian Museum of Nature - Kangaroo URL accessed January 6, 2007.  Another defensive tactic described by witnesses is catching the attacking dog  with the forepaws and disembowelling it with the hind legs.
#
# ['Along', 'dingos', 'canids', ',', 'introduced', 'species', 'like', 'foxes', 'feral', 'cats', 'also', 'pose', 'threat', 'kangaroo', 'populations', '.', 'Kangaroos', 'wallabies', 'adept', 'swimmers', ',', 'often', 'flee', 'waterways', 'presented', 'option', '.', 'If', 'pursued', 'water', ',', 'large', 'kangaroo', 'may', 'use', 'forepaws', 'hold', 'predator', 'underwater', 'drown', '.', 'Canadian', 'Museum', 'Nature', '-', 'Kangaroo', 'URL', 'accessed', 'January', '6', ',', '2007', '.', 'Another', 'defensive', 'tactic', 'described', 'witnesses', 'catching', 'attacking', 'dog', 'forepaws', 'disembowelling', 'hind', 'legs', '.']
#
#
# []
#
#
# []
#
#
# []
# Newborn joey sucking on a teat in the pouch
#
# ['Newborn', 'joey', 'sucking', 'teat', 'pouch']
# Kangaroos have developed a number of adaptations to a dry, infertile continent and highly variable climate. As with all marsupials, the young are born at a very early stage of development   after a gestation of 31 36 days. At this stage, only the forelimbs are somewhat developed, to allow the newborn to climb to the pouch and attach to a teat. In comparison, a human embryo at a similar stage of development would be about seven weeks old, and premature babies born at less than 23 weeks are usually not mature enough to survive. The joey will usually stay in the pouch for about nine months (180 320 days for the Western Grey) before starting to leave the pouch for small periods of time. It is usually fed by its mother until reaching 18 months.
#
# ['Kangaroos', 'developed', 'number', 'adaptations', 'dry', ',', 'infertile', 'continent', 'highly', 'variable', 'climate', '.', 'As', 'marsupials', ',', 'young', 'born', 'early', 'stage', 'development', 'gestation', '31', '36', 'days', '.', 'At', 'stage', ',', 'forelimbs', 'somewhat', 'developed', ',', 'allow', 'newborn', 'climb', 'pouch', 'attach', 'teat', '.', 'In', 'comparison', ',', 'human', 'embryo', 'similar', 'stage', 'development', 'would', 'seven', 'weeks', 'old', ',', 'premature', 'babies', 'born', 'less', '23', 'weeks', 'usually', 'mature', 'enough', 'survive', '.', 'The', 'joey', 'usually', 'stay', 'pouch', 'nine', 'months', '(', '180', '320', 'days', 'Western', 'Grey', ')', 'starting', 'leave', 'pouch', 'small', 'periods', 'time', '.', 'It', 'usually', 'fed', 'mother', 'reaching', '18', 'months', '.']
#
#
# []
# The female kangaroo is usually pregnant in permanence, except on the day she gives birth; however, she has the ability to freeze the development of an embryo until the previous joey is able to leave the pouch. This is known as diapause, and will occur in times of drought and in areas with poor food sources.  The composition of the milk produced by the mother varies according to the needs of the joey. In addition, the mother is able to produce two different kinds of milk simultaneously for the newborn and the older joey still in the pouch.
#
# ['The', 'female', 'kangaroo', 'usually', 'pregnant', 'permanence', ',', 'except', 'day', 'gives', 'birth', ';', 'however', ',', 'ability', 'freeze', 'development', 'embryo', 'previous', 'joey', 'able', 'leave', 'pouch', '.', 'This', 'known', 'diapause', ',', 'occur', 'times', 'drought', 'areas', 'poor', 'food', 'sources', '.', 'The', 'composition', 'milk', 'produced', 'mother', 'varies', 'according', 'needs', 'joey', '.', 'In', 'addition', ',', 'mother', 'able', 'produce', 'two', 'different', 'kinds', 'milk', 'simultaneously', 'newborn', 'older', 'joey', 'still', 'pouch', '.']
#
#
# []
# Unusually, during a dry period, males will not produce sperm, and females will only conceive if there has been enough rain to produce a large quantity of green vegetation.
#
# ['Unusually', ',', 'dry', 'period', ',', 'males', 'produce', 'sperm', ',', 'females', 'conceive', 'enough', 'rain', 'produce', 'large', 'quantity', 'green', 'vegetation', '.']
#
#
# []
# Hindleg of a kangaroo Kangaroos and wallabies have large, stretchy  tendons in their hind legs. They store elastic strain energy in the tendons of their large hind legs, providing most of the energy required for each hop by the spring action of the tendons rather than by any muscular effort. This is true in all animal species which have muscles connected to their skeleton through elastic elements such as tendons, but the effect is more pronounced in kangaroos.
#
# ['Hindleg', 'kangaroo', 'Kangaroos', 'wallabies', 'large', ',', 'stretchy', 'tendons', 'hind', 'legs', '.', 'They', 'store', 'elastic', 'strain', 'energy', 'tendons', 'large', 'hind', 'legs', ',', 'providing', 'energy', 'required', 'hop', 'spring', 'action', 'tendons', 'rather', 'muscular', 'effort', '.', 'This', 'true', 'animal', 'species', 'muscles', 'connected', 'skeleton', 'elastic', 'elements', 'tendons', ',', 'effect', 'pronounced', 'kangaroos', '.']
#
#
# []
# There is also a link between the hopping action and breathing: as the feet leave the ground, air is expelled from the lungs; bringing the feet forward ready for landing refills the lungs, providing further energy efficiency. Studies of kangaroos and wallabies have demonstrated that, beyond the minimum energy expenditure required to hop at all, increased speed requires very little extra effort (much less than the same speed increase in, say, a horse, dog or human), and that the extra energy is required to carry extra weight. For kangaroos, the key benefit of hopping is not speed to escape predators the top speed of a kangaroo is no higher than that of a similarly-sized quadruped, and the Australian native predators are in any case less fearsome than those of other continents but economy: in an infertile continent with highly variable weather patterns, the ability of a kangaroo to travel long distances at moderately high speed in search of food sources is crucial to survival.
#
# ['There', 'also', 'link', 'hopping', 'action', 'breathing', ':', 'feet', 'leave', 'ground', ',', 'air', 'expelled', 'lungs', ';', 'bringing', 'feet', 'forward', 'ready', 'landing', 'refills', 'lungs', ',', 'providing', 'energy', 'efficiency', '.', 'Studies', 'kangaroos', 'wallabies', 'demonstrated', ',', 'beyond', 'minimum', 'energy', 'expenditure', 'required', 'hop', ',', 'increased', 'speed', 'requires', 'little', 'extra', 'effort', '(', 'much', 'less', 'speed', 'increase', ',', 'say', ',', 'horse', ',', 'dog', 'human', ')', ',', 'extra', 'energy', 'required', 'carry', 'extra', 'weight', '.', 'For', 'kangaroos', ',', 'key', 'benefit', 'hopping', 'speed', 'escape', 'predators', 'top', 'speed', 'kangaroo', 'higher', 'similarly-sized', 'quadruped', ',', 'Australian', 'native', 'predators', 'case', 'less', 'fearsome', 'continents', 'economy', ':', 'infertile', 'continent', 'highly', 'variable', 'weather', 'patterns', ',', 'ability', 'kangaroo', 'travel', 'long', 'distances', 'moderately', 'high', 'speed', 'search', 'food', 'sources', 'crucial', 'survival', '.']
#
#
# []
# A sequencing project of the Kangaroo genome was started in 2004 as a collaboration between Australia (mainly funded by the state of Victoria) and the National Institutes of Health in the US.  Kangaroo hops in line for genome sequencing URL accessed January 6, 2007.  The genome of a marsupial such as the kangaroo is of great interest to scientists studying comparative genomics because marsupials are at an ideal degree of evolutionary divergence from humans: mice are too close and haven't developed many different functions, while birds are genetically too remote. The dairy industry has also expressed some interest in this project.
#
# ['A', 'sequencing', 'project', 'Kangaroo', 'genome', 'started', '2004', 'collaboration', 'Australia', '(', 'mainly', 'funded', 'state', 'Victoria', ')', 'National', 'Institutes', 'Health', 'US', '.', 'Kangaroo', 'hops', 'line', 'genome', 'sequencing', 'URL', 'accessed', 'January', '6', ',', '2007', '.', 'The', 'genome', 'marsupial', 'kangaroo', 'great', 'interest', 'scientists', 'studying', 'comparative', 'genomics', 'marsupials', 'ideal', 'degree', 'evolutionary', 'divergence', 'humans', ':', 'mice', 'close', "n't", 'developed', 'many', 'different', 'functions', ',', 'birds', 'genetically', 'remote', '.', 'The', 'dairy', 'industry', 'also', 'expressed', 'interest', 'project', '.']
#
#
# []
#
#
# []
#
#
# []
# Eye disease  is rare but not new among kangaroos.  The first official report of kangaroo blindness took place in 1994, in central New South Wales.  The following year, reports of blind kangaroos appeared in Victoria and South Australia.  By 1996, the disease had spread "across the desert to Western Australia".  Australian authorities were concerned that the disease could spread to other livestock and possibly humans.  Researchers at the Australian Animal Health Laboratories in Geelong detected a virus called the Wallal virus in two species of midge, believed to have been the carriers.       Veterinarians also discovered that less than three percent of kangaroos exposed to the virus developed blindness.
#
# ['Eye', 'disease', 'rare', 'new', 'among', 'kangaroos', '.', 'The', 'first', 'official', 'report', 'kangaroo', 'blindness', 'took', 'place', '1994', ',', 'central', 'New', 'South', 'Wales', '.', 'The', 'following', 'year', ',', 'reports', 'blind', 'kangaroos', 'appeared', 'Victoria', 'South', 'Australia', '.', 'By', '1996', ',', 'disease', 'spread', '``', 'across', 'desert', 'Western', 'Australia', "''", '.', 'Australian', 'authorities', 'concerned', 'disease', 'could', 'spread', 'livestock', 'possibly', 'humans', '.', 'Researchers', 'Australian', 'Animal', 'Health', 'Laboratories', 'Geelong', 'detected', 'virus', 'called', 'Wallal', 'virus', 'two', 'species', 'midge', ',', 'believed', 'carriers', '.', 'Veterinarians', 'also', 'discovered', 'less', 'three', 'percent', 'kangaroos', 'exposed', 'virus', 'developed', 'blindness', '.']
#
#
# []
#
#
# []
#
#
# []
# Before European settlement, the kangaroo was a very important animal for Australian Aborigines, for its meat, hide, bones and sinews. In addition, there were important Dreaming stories and ceremonies involving the kangaroo.  Aherrenge is a current kangaroo dreaming site in the Northern Territory. The game of Marn grook was played using a ball made from kangaroo  by the Kurnai people.
#
# ['Before', 'European', 'settlement', ',', 'kangaroo', 'important', 'animal', 'Australian', 'Aborigines', ',', 'meat', ',', 'hide', ',', 'bones', 'sinews', '.', 'In', 'addition', ',', 'important', 'Dreaming', 'stories', 'ceremonies', 'involving', 'kangaroo', '.', 'Aherrenge', 'current', 'kangaroo', 'dreaming', 'site', 'Northern', 'Territory', '.', 'The', 'game', 'Marn', 'grook', 'played', 'using', 'ball', 'made', 'kangaroo', 'Kurnai', 'people', '.']
#
#
# []
# Unlike many of the smaller macropods, kangaroos have fared well since European settlement. European settlers cut down forests to create vast grasslands for sheep and cattle grazing, added stock watering points in arid areas, and have substantially reduced the number of dingoes.
#
# ['Unlike', 'many', 'smaller', 'macropods', ',', 'kangaroos', 'fared', 'well', 'since', 'European', 'settlement', '.', 'European', 'settlers', 'cut', 'forests', 'create', 'vast', 'grasslands', 'sheep', 'cattle', 'grazing', ',', 'added', 'stock', 'watering', 'points', 'arid', 'areas', ',', 'substantially', 'reduced', 'number', 'dingoes', '.']
#
#
# []
# Kangaroos are shy and retiring by nature, and in normal circumstances present no threat to humans. Male kangaroos often "box" amongst each other, playfully, for dominance, or in competition for mates. The dexterity of their forepaws is utilised in both punching and grappling with the foe, but the real danger lies in a serious kick with the hindleg. The sharpened toenails can disembowel an opponent.
#
# ['Kangaroos', 'shy', 'retiring', 'nature', ',', 'normal', 'circumstances', 'present', 'threat', 'humans', '.', 'Male', 'kangaroos', 'often', '``', 'box', "''", 'amongst', ',', 'playfully', ',', 'dominance', ',', 'competition', 'mates', '.', 'The', 'dexterity', 'forepaws', 'utilised', 'punching', 'grappling', 'foe', ',', 'real', 'danger', 'lies', 'serious', 'kick', 'hindleg', '.', 'The', 'sharpened', 'toenails', 'disembowel', 'opponent', '.']
#
#
# []
# There are very few records of kangaroos attacking humans without provocation, however several such unprovoked attacks in 2004 spurred fears of a rabies-like disease possibly affecting the marsupials. The only reliably documented case of a fatality from a kangaroo attack occurred in New South Wales, in 1936. A hunter was killed when he tried to rescue his two dogs from a heated fray. Other suggested causes for erratic and dangerous kangaroo behaviour include extreme thirst and hunger.
#
# ['There', 'records', 'kangaroos', 'attacking', 'humans', 'without', 'provocation', ',', 'however', 'several', 'unprovoked', 'attacks', '2004', 'spurred', 'fears', 'rabies-like', 'disease', 'possibly', 'affecting', 'marsupials', '.', 'The', 'reliably', 'documented', 'case', 'fatality', 'kangaroo', 'attack', 'occurred', 'New', 'South', 'Wales', ',', '1936', '.', 'A', 'hunter', 'killed', 'tried', 'rescue', 'two', 'dogs', 'heated', 'fray', '.', 'Other', 'suggested', 'causes', 'erratic', 'dangerous', 'kangaroo', 'behaviour', 'include', 'extreme', 'thirst', 'hunger', '.']
#
#
# []
# In 2003, Lulu, an Eastern Grey, saved a farmer's life.  She received the RSPCA National Animal Valor Award on May 19 of the next year.
#
# ['In', '2003', ',', 'Lulu', ',', 'Eastern', 'Grey', ',', 'saved', 'farmer', "'s", 'life', '.', 'She', 'received', 'RSPCA', 'National', 'Animal', 'Valor', 'Award', 'May', '19', 'next', 'year', '.']
#
#
# []
#
#
# []
#
#
# []
# A "kangaroo crossing" sign on an Australian highway.
#
# ['A', '``', 'kangaroo', 'crossing', "''", 'sign', 'Australian', 'highway', '.']
# A kangaroo crossing a highway.
#
# ['A', 'kangaroo', 'crossing', 'highway', '.']
# A collision with a vehicle is capable of killing a kangaroo. Kangaroos dazzled by headlights or startled by engine noise have been known to leap in front of cars.  Since kangaroos in mid-bound can reach speeds of around 50 km/h (31 mph) and are relatively heavy, the force of impact can be severe.  Small vehicles may be destroyed, while larger vehicles may suffer engine damage. The risk of harm to vehicle occupants is greatly increased if the windscreen is the point of impact.  As a result, "kangaroo crossing" signs are commonplace in Australia.
#
# ['A', 'collision', 'vehicle', 'capable', 'killing', 'kangaroo', '.', 'Kangaroos', 'dazzled', 'headlights', 'startled', 'engine', 'noise', 'known', 'leap', 'front', 'cars', '.', 'Since', 'kangaroos', 'mid-bound', 'reach', 'speeds', 'around', '50', 'km/h', '(', '31', 'mph', ')', 'relatively', 'heavy', ',', 'force', 'impact', 'severe', '.', 'Small', 'vehicles', 'may', 'destroyed', ',', 'larger', 'vehicles', 'may', 'suffer', 'engine', 'damage', '.', 'The', 'risk', 'harm', 'vehicle', 'occupants', 'greatly', 'increased', 'windscreen', 'point', 'impact', '.', 'As', 'result', ',', '``', 'kangaroo', 'crossing', "''", 'signs', 'commonplace', 'Australia', '.']
#
#
# []
# Vehicles that frequent isolated roads, where roadside assistance may be scarce, are often fitted with "roo bars" to minimise damage caused by collision. Bonnet-mounted devices, designed to scare wildlife off the road with ultrasound and other methods, have been devised and marketed.
#
# ['Vehicles', 'frequent', 'isolated', 'roads', ',', 'roadside', 'assistance', 'may', 'scarce', ',', 'often', 'fitted', '``', 'roo', 'bars', "''", 'minimise', 'damage', 'caused', 'collision', '.', 'Bonnet-mounted', 'devices', ',', 'designed', 'scare', 'wildlife', 'road', 'ultrasound', 'methods', ',', 'devised', 'marketed', '.']
#
#
# []
# If a female is the victim of a collision, animal welfare groups ask that her pouch be checked for any surviving joey, in which case it may be removed to a wildlife sanctuary or veterinary surgeon for rehabilitation.  Likewise, when an adult kangaroo is injured in a collision, a vet, the RSPCA or the National Parks and Wildlife Service can be consulted for instructions on proper care. In New South Wales, rehabilitation of kangaroos is carried out by volunteers from WIRES.
#
# ['If', 'female', 'victim', 'collision', ',', 'animal', 'welfare', 'groups', 'ask', 'pouch', 'checked', 'surviving', 'joey', ',', 'case', 'may', 'removed', 'wildlife', 'sanctuary', 'veterinary', 'surgeon', 'rehabilitation', '.', 'Likewise', ',', 'adult', 'kangaroo', 'injured', 'collision', ',', 'vet', ',', 'RSPCA', 'National', 'Parks', 'Wildlife', 'Service', 'consulted', 'instructions', 'proper', 'care', '.', 'In', 'New', 'South', 'Wales', ',', 'rehabilitation', 'kangaroos', 'carried', 'volunteers', 'WIRES', '.']
#
#
# []
#
#
# []
#
#
# []
# Occasionally, individuals take on the task of rearing a recovered joey themselves. The rule-of-thumb says that if the joey is already covered with fur at the time of the accident (as opposed to still being in its embryonic stage), it stands a good chance of growing up properly. Lactose-free milk is required, otherwise the animal may develop blindness. They hop readily into a cloth bag when it is lowered in front of them approximately to the height where the mother's pouch would be. The joey's instinct is to "cuddle up", thereby endearing themselves to their keepers, but after hand-rearing a joey, it cannot usually be released into the wild and be expected to provide for itself immediately. Usually wildlife sanctuaries are willing to adopt kangaroos which are no longer practical, or have grown too large to contain, needing at least 1 acre and 7ft boundary fences for a fully grown kangaroo.
#
# ['Occasionally', ',', 'individuals', 'take', 'task', 'rearing', 'recovered', 'joey', '.', 'The', 'rule-of-thumb', 'says', 'joey', 'already', 'covered', 'fur', 'time', 'accident', '(', 'opposed', 'still', 'embryonic', 'stage', ')', ',', 'stands', 'good', 'chance', 'growing', 'properly', '.', 'Lactose-free', 'milk', 'required', ',', 'otherwise', 'animal', 'may', 'develop', 'blindness', '.', 'They', 'hop', 'readily', 'cloth', 'bag', 'lowered', 'front', 'approximately', 'height', 'mother', "'s", 'pouch', 'would', '.', 'The', 'joey', "'s", 'instinct', '``', 'cuddle', "''", ',', 'thereby', 'endearing', 'keepers', ',', 'hand-rearing', 'joey', ',', 'usually', 'released', 'wild', 'expected', 'provide', 'immediately', '.', 'Usually', 'wildlife', 'sanctuaries', 'willing', 'adopt', 'kangaroos', 'longer', 'practical', ',', 'grown', 'large', 'contain', ',', 'needing', 'least', '1', 'acre', '7ft', 'boundary', 'fences', 'fully', 'grown', 'kangaroo', '.']
#
#
# []
#
#
# []
#
#
# []
#
#
# []
# Kangaroos have been featured on coins, as well as being used as emblems and logos. They have also been used as mascots and in the naming of sports teams and are extremely well-represented in films, television, toys and souvenirs around the world.
#
# ['Kangaroos', 'featured', 'coins', ',', 'well', 'used', 'emblems', 'logos', '.', 'They', 'also', 'used', 'mascots', 'naming', 'sports', 'teams', 'extremely', 'well-represented', 'films', ',', 'television', ',', 'toys', 'souvenirs', 'around', 'world', '.']
#
#
# []
#
#
# []
#
#
# []
# *Dawson, Terence J. 1995. Kangaroos: Biology of the Largest Marsupials. Cornell University Press, Ithaca, New York. Second printing: 1998. ISBN 0-8014-8262-3.
#
# ['*Dawson', ',', 'Terence', 'J', '.', '1995', '.', 'Kangaroos', ':', 'Biology', 'Largest', 'Marsupials', '.', 'Cornell', 'University', 'Press', ',', 'Ithaca', ',', 'New', 'York', '.', 'Second', 'printing', ':', '1998', '.', 'ISBN', '0-8014-8262-3', '.']
#
#
# []
#
#
# []
#
#
# []
#
#
# []
#
#
# []
#
#
# []
#
#
# []
#
#
# []
#
#
# []
#
#
# []
#
#
# []
#
#
# []
#
#
# []
# The leopard (Panthera pardus) is an Old World mammal of the Felidae family and the smallest of the four 'big cats' of the genus Panthera, along with the tiger, lion, and jaguar. Leopards that are melanistic, either all-black or very dark in coloration, are known colloquially as Black Panthers.
#
# ['The', 'leopard', '(', 'Panthera', 'pardus', ')', 'Old', 'World', 'mammal', 'Felidae', 'family', 'smallest', 'four', "'big", 'cats', "'", 'genus', 'Panthera', ',', 'along', 'tiger', ',', 'lion', ',', 'jaguar', '.', 'Leopards', 'melanistic', ',', 'either', 'all-black', 'dark', 'coloration', ',', 'known', 'colloquially', 'Black', 'Panthers', '.']
#
#
# []
# Once distributed across southern Eurasia and Africa, from Korea to South Africa and Spain, it has disappeared from much of its former range and now chiefly occurs in subsaharan Africa. There are fragmented populations in Israel, the Indian subcontinent, Indochina, Malaysia, and western China. Despite the loss of range and continued population declines, the cat remains a least concern species;  its numbers are greater than that of the other Panthera species, all of which face more acute conservation concerns.
#
# ['Once', 'distributed', 'across', 'southern', 'Eurasia', 'Africa', ',', 'Korea', 'South', 'Africa', 'Spain', ',', 'disappeared', 'much', 'former', 'range', 'chiefly', 'occurs', 'subsaharan', 'Africa', '.', 'There', 'fragmented', 'populations', 'Israel', ',', 'Indian', 'subcontinent', ',', 'Indochina', ',', 'Malaysia', ',', 'western', 'China', '.', 'Despite', 'loss', 'range', 'continued', 'population', 'declines', ',', 'cat', 'remains', 'least', 'concern', 'species', ';', 'numbers', 'greater', 'Panthera', 'species', ',', 'face', 'acute', 'conservation', 'concerns', '.']
#
#
# []
# The species' success owes in part to its opportunistic hunting behaviour and its adaptability to a variety of habitats. The leopard consumes virtually any animal it can catch and ranges from rainforest to desert. Its ecological role resembles that of the similarly-sized cougar in the Americas. Physically, the spotted cat most closely resembles the jaguar, although it is of lighter build.
#
# ['The', 'species', "'", 'success', 'owes', 'part', 'opportunistic', 'hunting', 'behaviour', 'adaptability', 'variety', 'habitats', '.', 'The', 'leopard', 'consumes', 'virtually', 'animal', 'catch', 'ranges', 'rainforest', 'desert', '.', 'Its', 'ecological', 'role', 'resembles', 'similarly-sized', 'cougar', 'Americas', '.', 'Physically', ',', 'spotted', 'cat', 'closely', 'resembles', 'jaguar', ',', 'although', 'lighter', 'build', '.']
#
#
# []
#
#
# []
#
#
# []
# In Antiquity, it was believed that a leopard was a hybrid between a lion and a panther, as is reflected in its name, a Greek compound word derived from λέων léon ("lion") and πάρδος párdos ("male panther"), the latter related to Sanskrit पृदाकु pṝdāku ("snake, tiger, panther").
#
# ['In', 'Antiquity', ',', 'believed', 'leopard', 'hybrid', 'lion', 'panther', ',', 'reflected', 'name', ',', 'Greek', 'compound', 'word', 'derived', 'λέων', 'léon', '(', '``', 'lion', "''", ')', 'πάρδος', 'párdos', '(', '``', 'male', 'panther', "''", ')', ',', 'latter', 'related', 'Sanskrit', 'पृदाकु', 'pṝdāku', '(', '``', 'snake', ',', 'tiger', ',', 'panther', "''", ')', '.']
#
#
# []
# A panther can be any of several species of large felid; in North America, the term refers to cougars, in South America, jaguars, and elsewhere, leopards. Early naturalists distinguished between leopards and panthers not by colour (a common misconception), but by the length of the tail panthers having longer tails than leopards.
#
# ['A', 'panther', 'several', 'species', 'large', 'felid', ';', 'North', 'America', ',', 'term', 'refers', 'cougars', ',', 'South', 'America', ',', 'jaguars', ',', 'elsewhere', ',', 'leopards', '.', 'Early', 'naturalists', 'distinguished', 'leopards', 'panthers', 'colour', '(', 'common', 'misconception', ')', ',', 'length', 'tail', 'panthers', 'longer', 'tails', 'leopards', '.']
#
#
# []
# Felis pardus was one of the many species described in Linnaeus's 18th-century work, Systema Naturae.
#
# ['Felis', 'pardus', 'one', 'many', 'species', 'described', 'Linnaeus', "'s", '18th-century', 'work', ',', 'Systema', 'Naturae', '.']
#
#
# []
# The generic component of its modern scientific designation, Panthera pardus, is derived from Latin via Greek πάνθηρ pánthēr. A folk etymology held that it was a compound of παν pan ("all") and θηρ ("beast"). However, it is believed instead to derive from an Indo-Iranian word meaning "whitish-yellow, pale"; in Sanskrit, this word's reflex was पाण्डर pāṇḍara, from which was derived पुण्डरीक puṇḍárīka ("tiger", among other things), then borrowed into Greek.
#
# ['The', 'generic', 'component', 'modern', 'scientific', 'designation', ',', 'Panthera', 'pardus', ',', 'derived', 'Latin', 'via', 'Greek', 'πάνθηρ', 'pánthēr', '.', 'A', 'folk', 'etymology', 'held', 'compound', 'παν', 'pan', '(', '``', "''", ')', 'θηρ', '(', '``', 'beast', "''", ')', '.', 'However', ',', 'believed', 'instead', 'derive', 'Indo-Iranian', 'word', 'meaning', '``', 'whitish-yellow', ',', 'pale', "''", ';', 'Sanskrit', ',', 'word', "'s", 'reflex', 'पाण्डर', 'pāṇḍara', ',', 'derived', 'पुण्डरीक', 'puṇḍárīka', '(', '``', 'tiger', "''", ',', 'among', 'things', ')', ',', 'borrowed', 'Greek', '.']
#
#
# []
#
#
# []
#
#
# []
#
#
# []
# The leopard is an agile and graceful predator. Although smaller than the other members of Panthera, the leopard is still able to take large prey given a massive skull that well utilizes powerful jaw muscles.  Its body is comparatively long for a cat and its legs are short.  Head and body length is between 90 and 190 cm, the tail reaches 60 to 110cm. Shoulder height is 45 to 80 cm. Males are considerably larger than females and weigh 37 to 90 kg compared to 28 to 60 kg for females. Ronald M. Nowak: Walker's Mammals of the World. Johns Hopkins University Press, 1999 ISBN 0-8018-5789-9
#
# ['The', 'leopard', 'agile', 'graceful', 'predator', '.', 'Although', 'smaller', 'members', 'Panthera', ',', 'leopard', 'still', 'able', 'take', 'large', 'prey', 'given', 'massive', 'skull', 'well', 'utilizes', 'powerful', 'jaw', 'muscles', '.', 'Its', 'body', 'comparatively', 'long', 'cat', 'legs', 'short', '.', 'Head', 'body', 'length', '90', '190', 'cm', ',', 'tail', 'reaches', '60', '110cm', '.', 'Shoulder', 'height', '45', '80', 'cm', '.', 'Males', 'considerably', 'larger', 'females', 'weigh', '37', '90', 'kg', 'compared', '28', '60', 'kg', 'females', '.', 'Ronald', 'M.', 'Nowak', ':', 'Walker', "'s", 'Mammals', 'World', '.', 'Johns', 'Hopkins', 'University', 'Press', ',', '1999', 'ISBN', '0-8018-5789-9']
#
#
# []
# One of many spotted cats, a leopard may be mistaken for a cheetah or a jaguar. The leopard has rosettes rather than cheetah's simple spots, but they lack internal spots, unlike the jaguar. The leopard is larger and less lanky than the cheetah but smaller than the jaguar. The leopard's black, irregular rosettes serve as camouflage. They are circular in East Africa but tend to be square in southern Africa.  .
#
# ['One', 'many', 'spotted', 'cats', ',', 'leopard', 'may', 'mistaken', 'cheetah', 'jaguar', '.', 'The', 'leopard', 'rosettes', 'rather', 'cheetah', "'s", 'simple', 'spots', ',', 'lack', 'internal', 'spots', ',', 'unlike', 'jaguar', '.', 'The', 'leopard', 'larger', 'less', 'lanky', 'cheetah', 'smaller', 'jaguar', '.', 'The', 'leopard', "'s", 'black', ',', 'irregular', 'rosettes', 'serve', 'camouflage', '.', 'They', 'circular', 'East', 'Africa', 'tend', 'square', 'southern', 'Africa', '.', '.']
#
#
# []
# Leopards have been reported to reach 21 years of age in captivity.
#
# ['Leopards', 'reported', 'reach', '21', 'years', 'age', 'captivity', '.']
#
#
# []
#
#
# []
#
#
# []
#
#
# []
# A melanistic leopard, or "black panther"
#
# ['A', 'melanistic', 'leopard', ',', '``', 'black', 'panther', "''"]
# A melanistic morph of the leopard occurs particularly in mountainous areas and rain forests. The black color is heritable and caused by only one recessive gene locus. In some regions, for example on the Malayan Peninsula, up to half of all leopards are black. In Africa black leopards seem to be most common in the Ethiopian Highlands. While they are commonly called black panthers, the term is not applied exclusively to leopards. Black leopards are less successful on the African plains because their colouration makes them stand out.
#
# ['A', 'melanistic', 'morph', 'leopard', 'occurs', 'particularly', 'mountainous', 'areas', 'rain', 'forests', '.', 'The', 'black', 'color', 'heritable', 'caused', 'one', 'recessive', 'gene', 'locus', '.', 'In', 'regions', ',', 'example', 'Malayan', 'Peninsula', ',', 'half', 'leopards', 'black', '.', 'In', 'Africa', 'black', 'leopards', 'seem', 'common', 'Ethiopian', 'Highlands', '.', 'While', 'commonly', 'called', 'black', 'panthers', ',', 'term', 'applied', 'exclusively', 'leopards', '.', 'Black', 'leopards', 'less', 'successful', 'African', 'plains', 'colouration', 'makes', 'stand', '.']
#
#
# []
#
#
# []
#
#
# []
#
#
# []
# As of 1996, the leopard had the largest distribution of any wild cat,  although populations before and since have shown a declining trend and are fragmented outside of subsaharan Africa. The IUCN notes that within subsaharan Africa the species is "still numerous and even thriving in marginal habitats" where other large cats have disappeared, but that populations in North Africa may be extinct. In Asia, data on distribution are mixed: populations in Southwest and Central Asia are small and fragmented; in the northeast portion of the range, they are critically endangered; and in Indian, Southeast Asia, and China, the cat is still relatively abundant.  Leopards also like to live in grasslands, woodlands and riverside forests.
#
# ['As', '1996', ',', 'leopard', 'largest', 'distribution', 'wild', 'cat', ',', 'although', 'populations', 'since', 'shown', 'declining', 'trend', 'fragmented', 'outside', 'subsaharan', 'Africa', '.', 'The', 'IUCN', 'notes', 'within', 'subsaharan', 'Africa', 'species', '``', 'still', 'numerous', 'even', 'thriving', 'marginal', 'habitats', "''", 'large', 'cats', 'disappeared', ',', 'populations', 'North', 'Africa', 'may', 'extinct', '.', 'In', 'Asia', ',', 'data', 'distribution', 'mixed', ':', 'populations', 'Southwest', 'Central', 'Asia', 'small', 'fragmented', ';', 'northeast', 'portion', 'range', ',', 'critically', 'endangered', ';', 'Indian', ',', 'Southeast', 'Asia', ',', 'China', ',', 'cat', 'still', 'relatively', 'abundant', '.', 'Leopards', 'also', 'like', 'live', 'grasslands', ',', 'woodlands', 'riverside', 'forests', '.']
#
#
# []
#
#
# []
#
#
# []
# ...
#
#
# []
# Some farmers develop beetle banks to foster and provide cover for beneficial beetles.
#
# ['Some', 'farmers', 'develop', 'beetle', 'banks', 'foster', 'provide', 'cover', 'beneficial', 'beetles', '.']
#
#
# []
# Beetles of the Dermestidae family are often used in taxidermy to clean bones of remaining flesh.
#
# ['Beetles', 'Dermestidae', 'family', 'often', 'used', 'taxidermy', 'clean', 'bones', 'remaining', 'flesh', '.']
#
#
# []
#
#
# []
#
#
# []
# Ancient Egyptian scene depicting a scarab beetle
#
# ['Ancient', 'Egyptian', 'scene', 'depicting', 'scarab', 'beetle']
#
#
# []
# Several species of dung beetle, most notably Scarabaeus sacer (often referred to as "scarab"), enjoyed a sacred status among the ancient Egyptians, as the creatures were likened to the major god Khepri. Some scholars suggest that the Egyptians' practice of making mummies was inspired by the brooding process of the beetle. Many thousands of amulets and stamp seals have been excavated that depict the scarab. In many artifacts, the scarab is depicted pushing the sun along its course in the sky, much as scarabs push or roll balls of dung to their brood sites. During and following the New Kingdom, scarab amulets were often placed over the heart of the mummified deceased.
#
# ['Several', 'species', 'dung', 'beetle', ',', 'notably', 'Scarabaeus', 'sacer', '(', 'often', 'referred', '``', 'scarab', "''", ')', ',', 'enjoyed', 'sacred', 'status', 'among', 'ancient', 'Egyptians', ',', 'creatures', 'likened', 'major', 'god', 'Khepri', '.', 'Some', 'scholars', 'suggest', 'Egyptians', "'", 'practice', 'making', 'mummies', 'inspired', 'brooding', 'process', 'beetle', '.', 'Many', 'thousands', 'amulets', 'stamp', 'seals', 'excavated', 'depict', 'scarab', '.', 'In', 'many', 'artifacts', ',', 'scarab', 'depicted', 'pushing', 'sun', 'along', 'course', 'sky', ',', 'much', 'scarabs', 'push', 'roll', 'balls', 'dung', 'brood', 'sites', '.', 'During', 'following', 'New', 'Kingdom', ',', 'scarab', 'amulets', 'often', 'placed', 'heart', 'mummified', 'deceased', '.']
#
#
# []
# Some tribal groups, particularly in tropical parts of the world, use the colourful, iridescent elytra of certain beetles, especially certain Scarabaeidae, in ceremonies and as adornment.
#
# ['Some', 'tribal', 'groups', ',', 'particularly', 'tropical', 'parts', 'world', ',', 'use', 'colourful', ',', 'iridescent', 'elytra', 'certain', 'beetles', ',', 'especially', 'certain', 'Scarabaeidae', ',', 'ceremonies', 'adornment', '.']
#
#
# []
#
#
# []
#
#
# []
# Beetle collection at the Melbourne Museum, Australia
#
# ['Beetle', 'collection', 'Melbourne', 'Museum', ',', 'Australia']
# The study of beetles is called coleopterology, and its practitioners are coleopterists. Coleopterists have formed organisations to facilitate the study of beetles. Among these is The Coleopterists Society, an international organisation based in the United States. Such organisations may have both professionals and amateurs interested in beetles as members.
#
# ['The', 'study', 'beetles', 'called', 'coleopterology', ',', 'practitioners', 'coleopterists', '.', 'Coleopterists', 'formed', 'organisations', 'facilitate', 'study', 'beetles', '.', 'Among', 'The', 'Coleopterists', 'Society', ',', 'international', 'organisation', 'based', 'United', 'States', '.', 'Such', 'organisations', 'may', 'professionals', 'amateurs', 'interested', 'beetles', 'members', '.']
#
#
# []
# Research in this field is often published in peer-reviewed journals specific to the field of coleopterology, though journals dealing with general entomology also publish many papers on various aspects of beetle biology. Some of the journals specific to beetle research are:
#
# ['Research', 'field', 'often', 'published', 'peer-reviewed', 'journals', 'specific', 'field', 'coleopterology', ',', 'though', 'journals', 'dealing', 'general', 'entomology', 'also', 'publish', 'many', 'papers', 'various', 'aspects', 'beetle', 'biology', '.', 'Some', 'journals', 'specific', 'beetle', 'research', ':']
#
#
# []
# There is a thriving industry in the collection of beetle specimens for amateur and professional collectors. Many coleopterists prefer to collect beetle specimens for themselves, recording detailed information about each specimen and its habitat. Such collections add to the body of knowledge about the Coleoptera. Some countries have established laws governing or prohibiting the collection of certain rare (and often much sought after) species. One such beetle whose collection is illegal or restricted is the American burying beetle, Nicrophorus americanus.
#
# ['There', 'thriving', 'industry', 'collection', 'beetle', 'specimens', 'amateur', 'professional', 'collectors', '.', 'Many', 'coleopterists', 'prefer', 'collect', 'beetle', 'specimens', ',', 'recording', 'detailed', 'information', 'specimen', 'habitat', '.', 'Such', 'collections', 'add', 'body', 'knowledge', 'Coleoptera', '.', 'Some', 'countries', 'established', 'laws', 'governing', 'prohibiting', 'collection', 'certain', 'rare', '(', 'often', 'much', 'sought', ')', 'species', '.', 'One', 'beetle', 'whose', 'collection', 'illegal', 'restricted', 'American', 'burying', 'beetle', ',', 'Nicrophorus', 'americanus', '.']
#
#
# []
#
#
# []
#
#
# []
#
#
# []
#
#
# []
#
#
# []
#
#
# []
#
#
# []
#
#
# []
#
#
# []
# *  The Beetle Ring - A group of websites about beetles (Coleoptera).
#
# ['*', 'The', 'Beetle', 'Ring', '-', 'A', 'group', 'websites', 'beetles', '(', 'Coleoptera', ')', '.']
# *  Entomology - online insect museum, entomology, tips and tricks, how to spread and pin insects, etc.
#
# ['*', 'Entomology', '-', 'online', 'insect', 'museum', ',', 'entomology', ',', 'tips', 'tricks', ',', 'spread', 'pin', 'insects', ',', 'etc', '.']
#
#
# []
#
#
# []
#
#
# []
#
#
# []
#
#
# []
#
#
# []
# Turtles are reptilians of the Order Testudines (all living turtles belong to the crown group Chelonia), most of whose body is shielded by a special bony or cartilaginous shell developed from their ribs. The Order Testudines includes both extant (living) and extinct species, the earliest known turtles being from around 215 million years ago,  /ref> making turtles one of the oldest reptile groups, and a much more ancient group than lizards and snakes.  About 300 species are alive today; some are highly endangered.
#
# ['Turtles', 'reptilians', 'Order', 'Testudines', '(', 'living', 'turtles', 'belong', 'crown', 'group', 'Chelonia', ')', ',', 'whose', 'body', 'shielded', 'special', 'bony', 'cartilaginous', 'shell', 'developed', 'ribs', '.', 'The', 'Order', 'Testudines', 'includes', 'extant', '(', 'living', ')', 'extinct', 'species', ',', 'earliest', 'known', 'turtles', 'around', '215', 'million', 'years', 'ago', ',', '/ref', '>', 'making', 'turtles', 'one', 'oldest', 'reptile', 'groups', ',', 'much', 'ancient', 'group', 'lizards', 'snakes', '.', 'About', '300', 'species', 'alive', 'today', ';', 'highly', 'endangered', '.']
#
#
# []
# Like other reptiles, turtles are ectothermic (or "cold-blooded" Reptile blood isn't necessarily cold, as reptiles sun themselves and take other measures to stay warm. ). Like other amniotes (reptiles, dinosaurs, birds, and mammals), they breathe air and don't lay eggs underwater, though many species live in or around water. The largest turtles are aquatic.
#
# ['Like', 'reptiles', ',', 'turtles', 'ectothermic', '(', '``', 'cold-blooded', "''", 'Reptile', 'blood', "n't", 'necessarily', 'cold', ',', 'reptiles', 'sun', 'take', 'measures', 'stay', 'warm', '.', ')', '.', 'Like', 'amniotes', '(', 'reptiles', ',', 'dinosaurs', ',', 'birds', ',', 'mammals', ')', ',', 'breathe', 'air', "n't", 'lay', 'eggs', 'underwater', ',', 'though', 'many', 'species', 'live', 'around', 'water', '.', 'The', 'largest', 'turtles', 'aquatic', '.']
#
#
# []
#
#
# []
#
#
# []
# An American map turtle hatchling.
#
# ['An', 'American', 'map', 'turtle', 'hatchling', '.']
# Even though many turtles spend large amounts of their lives underwater, all turtles and tortoises breathe air, and must surface at regular intervals to refill their lungs. They can also spend much of their lives on dry land. Aquatic respiration in Australian freshwater turtles is currently being studied. Some species have large cloacal cavities that are lined with many finger-like projections. These projections, called "papillae", have a rich blood supply, and serve to increase the surface area of the cloaca. The turtles can take up dissolved oxygen from the water using these papillae, in much the same way that fish use gills to respire.
#
# ['Even', 'though', 'many', 'turtles', 'spend', 'large', 'amounts', 'lives', 'underwater', ',', 'turtles', 'tortoises', 'breathe', 'air', ',', 'must', 'surface', 'regular', 'intervals', 'refill', 'lungs', '.', 'They', 'also', 'spend', 'much', 'lives', 'dry', 'land', '.', 'Aquatic', 'respiration', 'Australian', 'freshwater', 'turtles', 'currently', 'studied', '.', 'Some', 'species', 'large', 'cloacal', 'cavities', 'lined', 'many', 'finger-like', 'projections', '.', 'These', 'projections', ',', 'called', '``', 'papillae', "''", ',', 'rich', 'blood', 'supply', ',', 'serve', 'increase', 'surface', 'area', 'cloaca', '.', 'The', 'turtles', 'take', 'dissolved', 'oxygen', 'water', 'using', 'papillae', ',', 'much', 'way', 'fish', 'use', 'gills', 'respire', '.']
#
#
# []
# Turtles lay eggs, like other reptiles, which are slightly soft and leathery. The eggs of the largest species are spherical, while the eggs of the rest are elongated. Their albumen is white and contains a different protein than bird eggs, such that it will not coagulate when cooked. Turtle eggs prepared to eat consist mainly of yolk. In some species, temperature determines whether an egg develops into a male or a female: a higher temperature causes a female, a lower temperature causes a male. Large numbers of eggs are deposited in holes dug into mud or sand. They are then covered and left to incubate by themselves.  When the turtles hatch they squirm their way to the surface and make for the water. There are no known species wherein the mother cares for the young.
#
# ['Turtles', 'lay', 'eggs', ',', 'like', 'reptiles', ',', 'slightly', 'soft', 'leathery', '.', 'The', 'eggs', 'largest', 'species', 'spherical', ',', 'eggs', 'rest', 'elongated', '.', 'Their', 'albumen', 'white', 'contains', 'different', 'protein', 'bird', 'eggs', ',', 'coagulate', 'cooked', '.', 'Turtle', 'eggs', 'prepared', 'eat', 'consist', 'mainly', 'yolk', '.', 'In', 'species', ',', 'temperature', 'determines', 'whether', 'egg', 'develops', 'male', 'female', ':', 'higher', 'temperature', 'causes', 'female', ',', 'lower', 'temperature', 'causes', 'male', '.', 'Large', 'numbers', 'eggs', 'deposited', 'holes', 'dug', 'mud', 'sand', '.', 'They', 'covered', 'left', 'incubate', '.', 'When', 'turtles', 'hatch', 'squirm', 'way', 'surface', 'make', 'water', '.', 'There', 'known', 'species', 'wherein', 'mother', 'cares', 'young', '.']
#
#
# []
# Sea turtles lay their eggs on dry sandy beaches. Immature sea turtles are not cared for by the adults. Most are endangered largely as a result of beach development and over hunting.
#
# ['Sea', 'turtles', 'lay', 'eggs', 'dry', 'sandy', 'beaches', '.', 'Immature', 'sea', 'turtles', 'cared', 'adults', '.', 'Most', 'endangered', 'largely', 'result', 'beach', 'development', 'hunting', '.']
#
#
# []
# Turtles can take many years to reach breeding age. Often turtles only breed every few years or more.
#
# ['Turtles', 'take', 'many', 'years', 'reach', 'breeding', 'age', '.', 'Often', 'turtles', 'breed', 'every', 'years', '.']
#
#
# []
# Researchers have recently discovered a turtle’s organs do not gradually break down or become less efficient over time, unlike most other animals. It was found that the liver, lungs and kidneys of a centenarian turtle are virtually indistinguishable from those of its immature counterpart. This has inspired genetic researchers to begin examining the turtle genome for longevity genes.  All but Ageless, Turtles Face Their Biggest Threat: Humans
#
# ['Researchers', 'recently', 'discovered', 'turtle', '’', 'organs', 'gradually', 'break', 'become', 'less', 'efficient', 'time', ',', 'unlike', 'animals', '.', 'It', 'found', 'liver', ',', 'lungs', 'kidneys', 'centenarian', 'turtle', 'virtually', 'indistinguishable', 'immature', 'counterpart', '.', 'This', 'inspired', 'genetic', 'researchers', 'begin', 'examining', 'turtle', 'genome', 'longevity', 'genes', '.', 'All', 'Ageless', ',', 'Turtles', 'Face', 'Their', 'Biggest', 'Threat', ':', 'Humans']
#
#
# []
#
#
# []
#
#
# []
#
#
# []
# Turtles are divided into three suborders, one of which, the Paracryptodira, is extinct. The two extant suborders are the Cryptodira and the Pleurodira. The Cryptodira is the larger of the two groups and includes all the marine turtles, the terrestrial tortoises, and many of the freshwater turtles. The Pleurodira are sometimes known as the side-necked turtles, a reference to the way they withdraw their heads into their shells. This smaller group consists primarily of various freshwater turtles.
#
# ['Turtles', 'divided', 'three', 'suborders', ',', 'one', ',', 'Paracryptodira', ',', 'extinct', '.', 'The', 'two', 'extant', 'suborders', 'Cryptodira', 'Pleurodira', '.', 'The', 'Cryptodira', 'larger', 'two', 'groups', 'includes', 'marine', 'turtles', ',', 'terrestrial', 'tortoises', ',', 'many', 'freshwater', 'turtles', '.', 'The', 'Pleurodira', 'sometimes', 'known', 'side-necked', 'turtles', ',', 'reference', 'way', 'withdraw', 'heads', 'shells', '.', 'This', 'smaller', 'group', 'consists', 'primarily', 'various', 'freshwater', 'turtles', '.']
#
#
# []
#
#
# []
#
#
# []
#
#
# []
# Different animals are called turtles, tortoises, or terrapins in different varieties of English
#
# ['Different', 'animals', 'called', 'turtles', ',', 'tortoises', ',', 'terrapins', 'different', 'varieties', 'English']
#
#
# []
#
#
# []
#
#
# []
#
#
# []
# Turtles, particularly small terrestrial and freshwater turtles, are commonly kept as pets. Among the most popular are Russian Tortoises, Greek spur-thighed tortoises and red-ear sliders (or terrapin). David Alderton (1986). An Interpet Guide to Reptiles & Amphibians, Salamander Books Ltd., London & New York.
#
# ['Turtles', ',', 'particularly', 'small', 'terrestrial', 'freshwater', 'turtles', ',', 'commonly', 'kept', 'pets', '.', 'Among', 'popular', 'Russian', 'Tortoises', ',', 'Greek', 'spur-thighed', 'tortoises', 'red-ear', 'sliders', '(', 'terrapin', ')', '.', 'David', 'Alderton', '(', '1986', ')', '.', 'An', 'Interpet', 'Guide', 'Reptiles', '&', 'Amphibians', ',', 'Salamander', 'Books', 'Ltd.', ',', 'London', '&', 'New', 'York', '.']
#
#
# []
#
#
# []
#
#
# []
#
#
# []
# *Addyaita: a giant turtle of Aldabra. It was reportedly 250-years old when it died at Kolkata Zoo on March 24, 2005.
#
# ['*Addyaita', ':', 'giant', 'turtle', 'Aldabra', '.', 'It', 'reportedly', '250-years', 'old', 'died', 'Kolkata', 'Zoo', 'March', '24', ',', '2005', '.']
#
#
# []
#
#
# []
#
#
# []
# * Iskandar, DT (2000). Turtles and Crocodiles of Insular Southeast Asia and New Guinea. ITB, Bandung.
#
# ['*', 'Iskandar', ',', 'DT', '(', '2000', ')', '.', 'Turtles', 'Crocodiles', 'Insular', 'Southeast', 'Asia', 'New', 'Guinea', '.', 'ITB', ',', 'Bandung', '.']
# * Pritchard, Pether C H (1979). Encyclopedia of Turtles. T.F.H. Publications.
#
# ['*', 'Pritchard', ',', 'Pether', 'C', 'H', '(', '1979', ')', '.', 'Encyclopedia', 'Turtles', '.', 'T.F.H', '.', 'Publications', '.']
#
#
# []
#
#
# []
#
#
# []
#
#
# []
# *  Turtles of the World: Extensive information on all known turtles, tortoises and terrapins, including key and quiz.
#
# ['*', 'Turtles', 'World', ':', 'Extensive', 'information', 'known', 'turtles', ',', 'tortoises', 'terrapins', ',', 'including', 'key', 'quiz', '.']
# *  - A website on all pet turtle species including a guide on caring for your turtles.
#
# ['*', '-', 'A', 'website', 'pet', 'turtle', 'species', 'including', 'guide', 'caring', 'turtles', '.']
# *  - Gulf Coast Turtle & Tortoise Society, A group dedicated to education & proper captive husbandry of turtles and tortoises.
#
# ['*', '-', 'Gulf', 'Coast', 'Turtle', '&', 'Tortoise', 'Society', ',', 'A', 'group', 'dedicated', 'education', '&', 'proper', 'captive', 'husbandry', 'turtles', 'tortoises', '.']
#
#
# []
#
#
# []
#
#
# []

# %%
labels
# Out:
# ['kangaroo',
#  'kangaroo',
#  'kangaroo',
#  'kangaroo',
#  'kangaroo',
#  'kangaroo',
#  'kangaroo',
#  'kangaroo',
#  'kangaroo',
#  'kangaroo']

# %%
file=open("text_data/S08_set1_a1.txt.clean",'r')

# %%
txt=file.readlines()

# %%
topic=txt[0]

# %%
topic=topic[:-1]

# %%
txt=txt[1:]

# %%
# Out:
# ['\n',
#  '\n',
#  'Turtles are reptilians of the Order Testudines (all living turtles belong to the crown group Chelonia), most of whose body is shielded by a special bony or cartilaginous shell developed from their ribs. The Order Testudines includes both extant (living) and extinct species, the earliest known turtles being from around 215 million years ago,  /ref> making turtles one of the oldest reptile groups, and a much more ancient group than lizards and snakes.  About 300 species are alive today; some are highly endangered.\n',
#  '\n',
#  'Like other reptiles, turtles are ectothermic (or "cold-blooded" Reptile blood isn\'t necessarily cold, as reptiles sun themselves and take other measures to stay warm. ). Like other amniotes (reptiles, dinosaurs, birds, and mammals), they breathe air and don\'t lay eggs underwater, though many species live in or around water. The largest turtles are aquatic.\n',
#  '\n',
#  '\n',
#  '\n',
#  'An American map turtle hatchling.\n',
#  'Even though many turtles spend large amounts of their lives underwater, all turtles and tortoises breathe air, and must surface at regular intervals to refill their lungs. They can also spend much of their lives on dry land. Aquatic respiration in Australian freshwater turtles is currently being studied. Some species have large cloacal cavities that are lined with many finger-like projections. These projections, called "papillae", have a rich blood supply, and serve to increase the surface area of the cloaca. The turtles can take up dissolved oxygen from the water using these papillae, in much the same way that fish use gills to respire.\n',
#  '\n',
#  'Turtles lay eggs, like other reptiles, which are slightly soft and leathery. The eggs of the largest species are spherical, while the eggs of the rest are elongated. Their albumen is white and contains a different protein than bird eggs, such that it will not coagulate when cooked. Turtle eggs prepared to eat consist mainly of yolk. In some species, temperature determines whether an egg develops into a male or a female: a higher temperature causes a female, a lower temperature causes a male. Large numbers of eggs are deposited in holes dug into mud or sand. They are then covered and left to incubate by themselves.  When the turtles hatch they squirm their way to the surface and make for the water. There are no known species wherein the mother cares for the young.\n',
#  '\n',
#  'Sea turtles lay their eggs on dry sandy beaches. Immature sea turtles are not cared for by the adults. Most are endangered largely as a result of beach development and over hunting.\n',
#  '\n',
#  'Turtles can take many years to reach breeding age. Often turtles only breed every few years or more.\n',
#  '\n',
#  'Researchers have recently discovered a turtle’s organs do not gradually break down or become less efficient over time, unlike most other animals. It was found that the liver, lungs and kidneys of a centenarian turtle are virtually indistinguishable from those of its immature counterpart. This has inspired genetic researchers to begin examining the turtle genome for longevity genes.  All but Ageless, Turtles Face Their Biggest Threat: Humans\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  'Turtles are divided into three suborders, one of which, the Paracryptodira, is extinct. The two extant suborders are the Cryptodira and the Pleurodira. The Cryptodira is the larger of the two groups and includes all the marine turtles, the terrestrial tortoises, and many of the freshwater turtles. The Pleurodira are sometimes known as the side-necked turtles, a reference to the way they withdraw their heads into their shells. This smaller group consists primarily of various freshwater turtles.\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  'Different animals are called turtles, tortoises, or terrapins in different varieties of English\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  'Turtles, particularly small terrestrial and freshwater turtles, are commonly kept as pets. Among the most popular are Russian Tortoises, Greek spur-thighed tortoises and red-ear sliders (or terrapin). David Alderton (1986). An Interpet Guide to Reptiles & Amphibians, Salamander Books Ltd., London & New York.\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '*Addyaita: a giant turtle of Aldabra. It was reportedly 250-years old when it died at Kolkata Zoo on March 24, 2005.\n',
#  '\n',
#  '\n',
#  '\n',
#  '* Iskandar, DT (2000). Turtles and Crocodiles of Insular Southeast Asia and New Guinea. ITB, Bandung.\n',
#  '* Pritchard, Pether C H (1979). Encyclopedia of Turtles. T.F.H. Publications.\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '*  Turtles of the World: Extensive information on all known turtles, tortoises and terrapins, including key and quiz.\n',
#  '*  - A website on all pet turtle species including a guide on caring for your turtles.\n',
#  '*  - Gulf Coast Turtle & Tortoise Society, A group dedicated to education & proper captive husbandry of turtles and tortoises.\n',
#  '\n',
#  '\n',
#  '\n']
